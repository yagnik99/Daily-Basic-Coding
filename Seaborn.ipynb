# %% [markdown]
# <a href="https://colab.research.google.com/github/yagnik99/Daily-Basic-Coding/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Install**

# %%
# Install
pip install seaborn   #or
conda install seaborn

# %%
# Import Seaborn
import seaborn as sns

# %% [markdown]
# ##Import Seaborn datasets

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  ...  ins_premium  ins_losses  abbrev
# 0    18.8     7.332    5.640  ...       784.55      145.08      AL
# 1    18.1     7.421    4.525  ...      1053.48      133.93      AK
# 2    18.6     6.510    5.208  ...       899.47      110.35      AZ
# 3    22.4     4.032    5.824  ...       827.34      142.39      AR
# 4    12.0     4.200    3.360  ...       878.41      165.63      CA
# 5    13.6     5.032    3.808  ...       835.50      139.91      CO
# 6    10.8     4.968    3.888  ...      1068.73      167.02      CT
# 7    16.2     6.156    4.860  ...      1137.87      151.48      DE
# 8     5.9     2.006    1.593  ...      1273.89      136.05      DC
# 9    17.9     3.759    5.191  ...      1160.13      144.18      FL
# 10   15.6     2.964    3.900  ...       913.15      142.80      GA
# 11   17.5     9.450    7.175  ...       861.18      120.92      HI
# 12   15.3     5.508    4.437  ...       641.96       82.75      ID
# ...

# %% [markdown]
# #**Distribution Plots**

# %%
sns.distplot(crash_df['not_distracted']) # Can doe kde= False to remove line, also can use bins to bucket data.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Comparing 2 distributions

# %%
sns.jointplot(x = 'speeding', y= 'alcohol', data = crash_df, kind = 'hex')  # kind = reg if want to have regression line between. Can also use 'kde' for KDE plot or hex for hexagonal

# %% [markdown]
# ##**Pair Plot**

# %%
sns.pairplot(crash_df)

# %% [markdown]
# ###Loading other dataset for more examples.

# %%
tips_df = sns.load_dataset('tips')
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.pairplot(tips_df, hue='sex')  #hue used to get for categorical data and palete for color

# %% [markdown]
# #**Styling**

# %%
import matplotlib.pyplot as plt

# %%
sns.set_style('dark')   # To set dark grid, can also set to white, whitegrid, dark and ticks
plt.figure(figsize = (8,4)) # To change fig size

sns.set_context('talk', font_scale=1.4)  # To set context and text, can have paper, talk, poster.

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %% [markdown]
# #**Categorical Plots**

# %% [markdown]
# ###**Bar Plots**

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df)

# %% [markdown]
# ###**Count Plot**
#
# ###To find count of categorical variables in data

# %%
sns.countplot(x='sex', data=tips_df)

# %% [markdown]
# ###**Box Plot**
#
# ### Shows quartile of data.

# %%
sns.set_style('white')   # To set dark grid, can also set to white, whitegrid, dark and ticks
plt.figure(figsize = (10,8)) # To change fig size
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')

# %%
sns.boxplot(tips_df['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###**Violin Plot**
#
# ###Similar to box plot.It is combination of box and KDE plot.

# %%
plt.figure(figsize = (12,10)) # To change fig size
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex', split=True)

# %% [markdown]
# ###**Strip Plot**
#
# ###Gives scatter points for categorical.

# %%
plt.figure(figsize = (10,8)) # To change fig size
sns.stripplot(x='day', y='total_bill', data=tips_df)

# %% [markdown]
# ###Can seperate it further by hue.

# %%
plt.figure(figsize = (10,8)) # To change fig size
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex')

# %% [markdown]
# ###Can seperatre further for both male and female by using dodge = True.

# %%
plt.figure(figsize = (10,8)) # To change fig size
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', dodge=True)

# %% [markdown]
# #**Palettes**
#
# ###Changing colors of data points.

# %%
plt.figure(figsize = (10,8)) # To change fig size
sns.set_style('white')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette='afmhot',dodge=True) # can use various palette for color change

plt.legend(loc=0)   # Move or set the label. here male/female - or can use other options like - upper right = 1, upper left = 2, lower left = 3, lower right = 4

# %% [markdown]
# #**Matrix Plots**

# %% [markdown]
# ###**Heat Map**

# %%
plt.figure(figsize = (10,8)) # To change fig size
sns.heatmap(crash_df.corr(), annot=True, cmap='Blues')

# %% [markdown]
# ### Heatmap on Pivot tables
# ### Loading new data set for that

# %%
import numpy as np
import pandas as pd

# %%
# Heatmap on Pivot tables
# Loading new data set for that

flights_df = sns.load_dataset('flights')
flights_df.head(3)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132

# %%
#Pivot Table
flights = flights_df.pivot_table(index='month', columns='year', values = 'passengers')
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
#Heat map
plt.figure(figsize = (10,8)) # To change fig size
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidths=1)   # Can use lines to seperate

# %% [markdown]
# #**Cluster Maps**
#
# ###Generally used to cluster data points based on distances. It shows hierarchical heat map.

# %%
# Loading iris dataset
iris = sns.load_dataset('iris')
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# We will plot species/ cluster data with species.
species = iris.pop('species')   # Removing species from df

# %%
# Species removed
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
# Clustering.
sns.clustermap(iris)    # It shows nearby datapoints but not clear intution from this.

# %% [markdown]
# #**Facet Grid**

# %%
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height = 4, aspect = 1.3)    # Creating empty grid

# %%
sns.set_style('white')
sns.set_context('paper')
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height = 4, aspect = 1.3, col_order = ['Dinner', 'Lunch'], palette = 'Set1')    # Creating empty grid , col_order to set column order
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %% [markdown]
# #**Regression Plots**

# %%
tips_df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.regplot(x= tips_df['tip'], y= tips_df['total_bill'])

# %%
plt.rcParams['figure.figsize'] = (12, 5)  # Change fig size
sns.regplot(x= 'tip', y= 'total_bill', data=tips_df, scatter_kws={"color": "black"}, line_kws={"color": "red"})

# %% [markdown]
# ###Also we have sns.lmplot for regression which supports hue as well.

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df)

# %% [markdown]
# ### For more content and cheat sheet - https://github.com/yagnik99/Daily-Basic-Coding
#
# ### https://www.youtube.com/watch?v=6GUZXDef2U0
